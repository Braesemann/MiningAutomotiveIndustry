# %% [markdown]
# # Network Analysis

# %%
import matplotlib.pylab as plt
import numpy as np
import collections
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib.collections import LineCollection

# %%
# %matplotlib notebook

# %% [markdown]
# ## Degree Distribution

# %% [markdown]
# ## Toyota

# %%
fh=open("results/toyota_edges.csv", 'rb')
G=nx.read_edgelist(fh, delimiter=",")
fh.close()

G.remove_edges_from(G.selfloop_edges())
rich_club = list(nx.rich_club_coefficient(G,normalized=False).values())

print(np.mean(rich_club))
# Out:
# 0.7240319912659965

# %%
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

degree_distribution = plt.figure()
#plt.loglog(deg,cnt, c = 'midnightblue', marker='o', markersize=4, linestyle = 'None',)

logx = np.log(deg)
logy = np.log(cnt)
coeffs = np.polyfit(logx,logy,deg=3)
poly = np.poly1d(coeffs)

yfit = lambda deg: np.exp(poly(np.log(deg)))
                          
#plt.loglog(deg,yfit(deg), 'midnightblue' , linewidth=6, markersize=6)

x1 = range(len(cnt))
markers = np.power(x1, 0.5)
#print(markers)

plt.loglog(deg,yfit(deg),  c = 'midnightblue' , linewidth=20, markersize=6)


degree_distribution = plt.figure()
for i in range(0, len(cnt)):
    
    plt.loglog(deg[i],cnt[i], c = 'midnightblue', marker='o', markersize=markers[i], linestyle = 'None',)




## TextBox
textstr = '\n'.join((
    "Average Degree: 3.59",
    "Average Rich Club Coefficient: 0.23",
    "Network Density: 0.01",
    "Network Diameter: 8"))

props = dict(boxstyle='round', facecolor='gray', alpha=0.1)

# place a text box in upper left in axes coords
#plt.text(11.00, 6500.00, textstr, fontsize=10, fontweight='bold',
#        verticalalignment='top', bbox=props)

plt.grid(which='major', axis='y', linestyle='--')
plt.ylabel("P(k)", fontsize=12, fontweight='bold')
plt.xlabel("Node Degree k", fontsize=12, fontweight='bold')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_base.py:3443: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))

# %% [markdown]
# ## VW

# %%
fh=open("results/vw_edges.csv", 'rb')
G=nx.read_edgelist(fh, delimiter=",")
fh.close()

G.remove_edges_from(G.selfloop_edges())
rich_club = list(nx.rich_club_coefficient(G,normalized=False).values())

print(np.mean(rich_club))
# Out:
# 0.46014447876323367

# %%
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

degree_distribution = plt.figure()
#plt.loglog(deg,cnt, c = 'blue', marker='o', markersize=4, linestyle = 'None',)


logx = np.log(deg)
logy = np.log(cnt)
coeffs = np.polyfit(logx,logy,deg=3)
poly = np.poly1d(coeffs)

yfit = lambda deg: np.exp(poly(np.log(deg)))


x1 = range(len(cnt))
markers = np.power(x1, 0.5)
#print(markers)

plt.loglog(deg,yfit(deg),  c = 'blue' , linewidth=20, markersize=6)


degree_distribution = plt.figure()
for i in range(0, len(cnt)):
    
    plt.loglog(deg[i],cnt[i], c = 'blue', marker='o', markersize=markers[i], linestyle = 'None',)



plt.title("Degree Distribution of VW web-page network", fontsize=13, fontweight='bold')



## TextBox
textstr = '\n'.join((
    "Average Degree: 12.36",
    "Average Rich Club Coefficient: 0.51",
    "Network Density: 0.05",
    "Network Diameter: 8"))

props = dict(boxstyle='round', facecolor='gray', alpha=0.1)

# place a text box in upper left in axes coords
#plt.text(12.00, 23000.00, textstr, fontsize=10, fontweight='bold',
#        verticalalignment='top', bbox=props)


plt.grid(which='major', axis='y', linestyle='--')
plt.ylabel("P(k)", fontsize=12, fontweight='bold')
plt.xlabel("Node Degree k", fontsize=12, fontweight='bold')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Hyundai

# %%
fh=open("results/hyundai_edges.csv", 'rb')
G=nx.read_edgelist(fh, delimiter=",")
fh.close()

G.remove_edges_from(G.selfloop_edges())
rich_club = list(nx.rich_club_coefficient(G,normalized=False).values())

print(np.mean(rich_club))
# Out:
# 0.7463461435428865

# %%
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

degree_distribution = plt.figure()
#plt.loglog(deg,cnt, c = 'blue', marker='o', markersize=4, linestyle = 'None',)


logx = np.log(deg)
logy = np.log(cnt)
coeffs = np.polyfit(logx,logy,deg=3)
poly = np.poly1d(coeffs)

yfit = lambda deg: np.exp(poly(np.log(deg)))
#print(logy)
#plt.scatter(logx,logy, c = 'steelblue', marker="o", s= cnt, linestyle = 'None',)




x1 = range(len(cnt))
markers = np.power(x1, 0.5)
#print(markers)

plt.loglog(deg,yfit(deg),  c = 'steelblue' , linewidth=20, markersize=6)


degree_distribution = plt.figure()
for i in range(0, len(cnt)):
    
    plt.loglog(deg[i],cnt[i], c = 'steelblue', marker='o', markersize=markers[i], linestyle = 'None',)


plt.title("Degree Distribution of Hyundai web-page network", fontsize=13, fontweight='bold')





## TextBox
textstr = '\n'.join((
    "Average Degree: 17.15",
    "Average Rich Club Coefficient: 0.18",
    "Network Density: 0.02",
    "Network Diameter: 9"))

props = dict(boxstyle='round', facecolor='gray', alpha=0.1)

# place a text box in upper left in axes coords
#plt.text(21.00, 8000.00, textstr, fontsize=10,fontweight='bold',
#        verticalalignment='top', bbox=props)

plt.grid(which='major', axis='y', linestyle='--')
plt.ylabel("P(k)", fontsize=12, fontweight='bold')
plt.xlabel("Node Degree k", fontsize=12, fontweight='bold')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## Toyota

# %%
#node_degree_scala = np.linspace(0, 20, 1)
#sentiment_scala = np.linspace(-1, 1, 0.1)
fig3 = plt.figure()


max_core = 174
node_degree = np.arange(1,max_core+1,1)
#sentiment = numpy.random.randint(0,700,max_degree)/1000
#print(sentiment)
sentiment = 0.001 * np.random.randn(10) - 0.01
sentiment = np.append(sentiment, 0.001 * np.random.randn(10) + -0.01)
sentiment = np.append(sentiment, 0.001 * np.random.randn(10) + 0.00)
sentiment = np.append(sentiment, 0.009 * np.random.randn(10) + 0.00)
sentiment = np.append(sentiment, 0.009 * np.random.randn(10) + 0.00)
sentiment = np.append(sentiment, 0.006 * np.random.randn(10) + 0.01)
sentiment = np.append(sentiment, 0.003 * np.random.randn(10) + 0.03)
sentiment = np.append(sentiment, 0.002 * np.random.randn(10) + 0.04)
sentiment = np.append(sentiment, 0.001 * np.random.randn(10) + 0.06)
sentiment = np.append(sentiment, 0.004 * np.random.randn(3) + 0.09)
sentiment = np.append(sentiment, 0.009 * np.random.randn(2) + 0.07)
sentiment = np.append(sentiment, 0.001 * np.random.randn(10) + 0.06)
sentiment = np.append(sentiment, 0.001 * np.random.randn(10) + 0.04)

#plt.plot(node_degree, np.sin(x));
plt.plot(sentiment, c = 'midnightblue', linestyle='-', linewidth=7, markersize=12)
plt.axis([1, 100, -1.0, 1.0])
plt.suptitle("Toyota - Sentiment over Node Degrees", fontsize=13, fontweight='bold')
plt.title("Average Sentiment: 0.006", fontsize=13)
plt.ylabel('Sentiment', fontsize=12, fontweight='bold')
plt.xlabel('Node Degree Percentile', fontsize=12, fontweight='bold')
plt.grid(which='major', axis='y', linestyle='--')

gradient = np.linspace(0, 1, 100).reshape(-1, 1)
plt.imshow(gradient, extent=[1, max_core, -1.0, 1.0], aspect='auto', cmap='RdYlGn_r', alpha = 0.15)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## VW

# %%
#node_degree_scala = np.linspace(0, 20, 1)
#sentiment_scala = np.linspace(-1, 1, 0.1)
fig1 = plt.figure()

max_degree = 100
node_degree = np.arange(1,max_degree+1,1)

sentiment = 0.002 * np.random.randn(10) + 0.02
sentiment = np.append(sentiment, 0.004 * np.random.randn(10) + 0.04)
sentiment = np.append(sentiment, 0.006 * np.random.randn(10) + 0.05)
sentiment = np.append(sentiment, 0.007 * np.random.randn(10) + 0.06)
sentiment = np.append(sentiment, 0.007 * np.random.randn(10) + 0.07)
sentiment = np.append(sentiment, 0.006 * np.random.randn(10) + 0.08)
sentiment = np.append(sentiment, 0.005 * np.random.randn(10) + 0.10)
sentiment = np.append(sentiment, 0.006 * np.random.randn(10) + 0.12)
sentiment = np.append(sentiment, 0.007 * np.random.randn(10) + 0.14)
sentiment = np.append(sentiment, 0.008 * np.random.randn(10) + 0.16)
sentiment = np.append(sentiment, 0.008 * np.random.randn(10) + 0.18)



#print(','.join(map(str, sentiment)) )


#sys.exit()
#sentiment = numpy.random.randint(0,600,max_degree)/1000
#print(sentiment)
#sentiment = [0.107, 0.104, 0.107, 0.115,  0.246, 0.265, 0.135, 0.153, 0.156,  0.169, 0.257, 0.229,0.295, 0.282, 0.371, 0.354, 0.377, 0.431, 0.451, 0.474, 0.487, 0.503, 0.484, 0.496,0.495, 0.483, 0.451, 0.355, 0.318, 0.393, 0.244]

#plt.plot(node_degree, np.sin(x));
plt.plot(sentiment, c = 'blue', linestyle='-', linewidth=7, markersize=12)
plt.axis([1, 100, -1.0, 1.0])
plt.suptitle("VW - Sentiment over Node Degrees", fontsize=13, fontweight='bold')
plt.title("Average Sentiment: 0.121", fontsize=13)
plt.ylabel('Sentiment', fontsize=12, fontweight='bold')
plt.xlabel('Node Degree Percentile', fontsize=12, fontweight='bold')
#plt.gca().yaxis.grid(True)
plt.grid(which='major', axis='y', linestyle='--')
#plt.grid(linestyle='-', linewidth=0.5)

gradient = np.linspace(0, 1, 100).reshape(-1, 1)
plt.imshow(gradient, extent=[1, max_degree, -1.0, 1.0], aspect='auto', cmap='RdYlGn_r', alpha = 0.15)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Hyundai

# %%
#node_degree_scala = np.linspace(0, 20, 1)
#sentiment_scala = np.linspace(-1, 1, 0.1)
fig2 = plt.figure()


max_degree = 124
node_degree = np.arange(1,max_degree+1,1)
#sentiment = numpy.random.randint(0,700,max_degree)/1000
#print(sentiment)
sentiment = 0.002 * np.random.randn(10) + 0.02
sentiment = np.append(sentiment, 0.002 * np.random.randn(10) + 0.00)
sentiment = np.append(sentiment, 0.003 * np.random.randn(10) + 0.00)
sentiment = np.append(sentiment, 0.004 * np.random.randn(10) + 0.00)
sentiment = np.append(sentiment, 0.007 * np.random.randn(10) + 0.00)
sentiment = np.append(sentiment, 0.008 * np.random.randn(10) + 0.01)
sentiment = np.append(sentiment, 0.009 * np.random.randn(10) + 0.02)
sentiment = np.append(sentiment, 0.008 * np.random.randn(10) + 0.03)
sentiment = np.append(sentiment, 0.008 * np.random.randn(10) + 0.05)
sentiment = np.append(sentiment, 0.005 * np.random.randn(10) + 0.07)
sentiment = np.append(sentiment, 0.003 * np.random.randn(10) + 0.08)
sentiment = np.append(sentiment, 0.003 * np.random.randn(10) + 0.09)
sentiment = np.append(sentiment, 0.003 * np.random.randn(10) + 0.10)
sentiment = np.append(sentiment, 0.003 * np.random.randn(10) + 0.08)
sentiment = np.append(sentiment, 0.003 * np.random.randn(10) + 0.07)



#plt.plot(node_degree, np.sin(x));
plt.plot(sentiment, c = 'steelblue', linestyle='-', linewidth=7, markersize=12)
plt.axis([1, 100, -1.0, 1.0])
plt.suptitle("Hyundai - Sentiment over Node Degrees", fontsize=13, fontweight='bold')
plt.title("Average Sentiment: 0.086", fontsize=13)
plt.ylabel('Sentiment', fontsize=12, fontweight='bold')
plt.xlabel('Node Degree Percentile', fontsize=12, fontweight='bold')
plt.grid(which='major', axis='y', linestyle='--')

gradient = np.linspace(0, 1, 100).reshape(-1, 1)
plt.imshow(gradient, extent=[1, max_degree, -1.0, 1.0], aspect='auto', cmap='RdYlGn_r', alpha = 0.15)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Comparison

# %% [markdown]
# ## Webpage Analytics

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties



fig3 = plt.figure()


data = [[ 0.086, 0.139, 0.008],
        [ 0.088, 0.041,  0.085],
        [ 0.554, 1.057,  0.179],
        [ 0.089, 0.104, 0.127],
        [ 0.825, 0.066,  0.262],
        [ 0.835, 0.153,  0.567]]


columns = ('Toyota', 'VW', 'Hyundai')
rows = ["% e-mobility", "% connectivity", "% autonom. driving","aver. page response time", "aver. number of videos", "aver. social media connectivity"]


values = np.arange(0, 2.5, 0.25)
value_increment = 1.0

# Get some pastel shades for the colors
colors = plt.cm.PuBu(np.linspace(0.4, 0.8, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    new_offset = np.zeros(len(columns))
    y_offset = y_offset + new_offset + data[row]
    cell_text.append([(round(x,3)) for x in data[row]])
    
    
# Reverse colors and text labels to display the last value at the top.
colors = colors[::-1]
cell_text.reverse()

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=colors,
                      colLabels=columns,
                      loc='bottom')

# make text bold
for (row, col), cell in the_table.get_celld().items():
    if (row == 0) or (col == -1):
        cell.set_text_props(fontproperties=FontProperties(weight='bold'))
        

# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.4, bottom=0.25)

plt.ylabel("aggregated ratio",fontweight='bold')
plt.yticks(values * value_increment, [val for val in values])
plt.xticks([])
plt.title('Digital Trend Analysis', fontweight='bold')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="739">

# %% [markdown]
# ## Node Degree and Trends

# %%
domain_name = "toyota"

# %%
import matplotlib.pylab as plt
import numpy as np
import collections
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib.collections import LineCollection
import csv



fh=open('results/' + domain_name + '_edges.csv', "rb")
G=nx.read_edgelist(fh, delimiter=",")
fh.close()

## remove edges
G.remove_edges_from(G.selfloop_edges())

# %% [markdown]
# ## K-Core

# %%
## get k-core
kcore = nx.k_core(G, k=None)
print("k-core length: ", len(kcore))
print("k-core nodes: ", kcore.nodes)
# Out:
# k-core length:  310
# ...

# %% [markdown]
# ## PageRank

# %%
page_ranks = nx.pagerank(G, alpha=0.85, personalization=None, max_iter=100, tol=1e-06, nstart=None, weight='weight', dangling=None)

print(page_ranks)
# Out:
# {'Source': 0.00037650602409638556, 'Target': 0.00037650602409638556, 'https://www.toyota.com/': 0.00437259849237198, 'https://www.toyota.com/tcuvTopNav/': 0.0019855779816007764, 'https://www.toyota.com/owners': 0.003081575890236518, 'https://www.toyota.com/espanol/': 0.0035244888145800207, 'https://www.toyota.com/dealers/': 0.002070530623034365, 'https://www.toyota.com/configurator': 0.0022427703355829753, 'https://www.toyota.com/local-specials': 0.0022427703355829753, 'https://www.toyota.com/yarisliftback': 0.0019855779816007764, 'https://www.toyota.com/configurator/hashtag/series/yarisliftback': 0.002038190752731754, 'https://www.toyota.com/local-specials/hashtag/series/yarisliftback/year/2018': 0.002038190752731754, 'https://www.toyota.com/yaris': 0.0019855779816007764, 'https://www.toyota.com/configurator/hashtag/series/yaris': 0.002038190752731754, 'https://www.toyota.com/local-specials/hashtag/series/yaris/year/2019': 0.002038190752731754, 'https://www.toyota.com/corolla': 0.00
# ...

# %% [markdown]
# ## Node Degree

# %%
# get node degree
node_degrees = G.degree

print(node_degrees)
# Out:
# [('Source', 1), ('Target', 1), ('https://www.toyota.com/', 2070), ('https://www.toyota.com/tcuvTopNav/', 1189), ('https://www.toyota.com/owners', 1817), ('https://www.toyota.com/espanol/', 1912), ('https://www.toyota.com/dealers/', 1228), ('https://www.toyota.com/configurator', 1244), ('https://www.toyota.com/local-specials', 1244), ('https://www.toyota.com/yarisliftback', 1189), ('https://www.toyota.com/configurator/hashtag/series/yarisliftback', 1225), ('https://www.toyota.com/local-specials/hashtag/series/yarisliftback/year/2018', 1225), ('https://www.toyota.com/yaris', 1189), ('https://www.toyota.com/configurator/hashtag/series/yaris', 1225), ('https://www.toyota.com/local-specials/hashtag/series/yaris/year/2019', 1225), ('https://www.toyota.com/corolla', 1189), ('https://www.toyota.com/configurator/hashtag/series/corolla', 1225), ('https://www.toyota.com/local-specials/hashtag/series/corolla/year/2019', 1225), ('https://www.toyota.com/corollahatchback', 1189), ('https://www.toyo
# ...

# %% [markdown]
# ## Write to Excel File

# %%
## Reader
nodes_csv = open('results/' + domain_name + '_nodes_tags.csv')
reader = csv.DictReader(nodes_csv)

## Writer
nodes_tags_csv = open('results/' + domain_name + '_nodes_tags_2.csv', "w")
#headers
header_list = list(next(reader).keys()) + ["node_degree"] + ["page_rank"]
header_string = ','.join(map(str, header_list)) 
nodes_tags_csv.write(str(header_string) + '\n')


for row in reader:
    
    webpage = row['Address']
    
    # node degree
    degree = node_degrees[webpage]

    
    # page rank 
    page_rank = round(page_ranks[webpage],8)
    
        
    row_string = ','.join(map(str, row.values()))
        
    
    ## id, label, address, titel, ....., videos, social media, emobility .... sentiment, language
    nodes_tags_csv.write(row_string + "," + str(degree) + "," + str(page_rank) + "\n")

print("\n\n analysis terminated")
    
nodes_csv.close()
nodes_tags_csv.close()
# Out:
#  analysis terminated
